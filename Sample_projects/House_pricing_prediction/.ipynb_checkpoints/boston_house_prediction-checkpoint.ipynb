# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
boston = pd.read_csv("boston_housing.csv")
boston_X = df.drop(columns=["MEDV"]).values
boston_y = df["MEDV"].values

# %%
boston_X.shape
# Out:
# (506, 13)

# %%
boston_y.shape
# Out:
# (506,)
